# %%
import findspark
findspark.init()
import pyspark
sc = pyspark.SparkContext(appName='Start')
sc
# Out:
# <SparkContext master=local[*] appName=Start>

# %%
#Q1
#Install Java SE
#Install Spark 2.4.3 (7 May 2019)
#Install Hadoop WinUtils
#Configure your environment
#install findspark

# %%
#Q2

# %%
import random
def inside(p):
    x, y = random.random(), random.random()
    return x*x + y*y < 1

NUM_SAMPLES = 10000
count = sc.parallelize(range(0, NUM_SAMPLES)) \
 		.filter(inside).count()
print("Pi is roughly %f" % (4.0 * count / NUM_SAMPLES))
# Out:
# Pi is roughly 3.134000

# %%
#Q3

# %%
text_file = sc.textFile("/Users/kahoyeung/Documents/ITP4869_LAB/sample.txt")
counts = text_file.flatMap(lambda line: line.split(" ")) \
             .map(lambda word: (word, 1)) \
             .reduceByKey(lambda a, b: a + b)
counts
text_file = open("/Users/kahoyeung/Documents/ITP4869_LAB/counts/part-00001", "r")

print(text_file.read())
# Out:
# ('Gutenberg', 21)
# ('Ulysses,', 3)
# ('by', 1175)
# ('James', 29)
# ('Joyce', 4)
# ('This', 59)
# ('eBook', 5)
# ('for', 1791)
# ('the', 13609)
# ('cost', 8)
# ('and', 6551)
# ('with', 2391)
# ('almost', 25)
# ('You', 235)
# ('copy', 15)
# ('it', 1680)
# ('or', 939)
# ('under', 208)
# ('terms', 31)
# ('License', 8)
# ('included', 6)
# ('Title:', 1)
# ('Release', 1)
# ('August', 3)
# ('2008', 1)
# ('[EBook', 1)
# ('#4300]', 1)
# ('Updated:', 1)
# ('17,', 1)
# ('encoding:', 1)
# ('START', 1)
# ('PROJECT', 4)
# ('EBOOK', 2)
# ('Produced', 2)
# ('Col', 2)
# ('David', 10)
# ('I', 2430)
# (']', 18)
# ('Stately,', 1)
# ('plump', 18)
# ('Buck', 102)
# ('Mulligan', 115)
# ('from', 1013)
# ('bearing', 25)
# ('a', 5841)
# ('on', 1894)
# ('which', 457)
# ('lay', 54)
# ('crossed.', 1)
# ('A', 567)
# ('ungirdled,', 1)
# ('behind', 110)
# ('him', 1112)
# ('mild', 7)
# ('morning', 65)
# ('He', 909)
# ('held', 59)
# ('intoned:', 1)
# ('ad', 21)
# ('altare', 2)
# ('Halted,', 2)
# ('peered', 11)
# ...
